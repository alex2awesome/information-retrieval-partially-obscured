# %%
import re
import json

# %%
def parse_input(text):
    #Seperate by website_url
    articles = re.split(r'(www\.[^\s]+)', text)
    
    parsed_articles = []
    
    for i in range(1, len(articles), 2):
        article_url = articles[i].strip()
        article_content = articles[i+1].strip()
        
        sources = re.findall(r'\*\*(.*?)\*\*\n(.*?)(?=\*\*|$)', article_content, re.DOTALL)
        source_dict = {source.strip(): summary.strip() for source, summary in sources}
        
        parsed_articles.append({
            'article_url': article_url,
            'Sources': source_dict
        })
    
    return json.dumps(parsed_articles, indent=2, ensure_ascii=False)

# %%
sources = open('sources_data_70b__200000_200100.txt', 'r')
x = sources.read()

# %%
output = parse_input(x)
print(output)
# Out:
# [
#   {
#     "article_url": "www.businessinsider.es/coronavirus-aviones-podrian-volar-asientos-centrales-vacios-622757",
#     "Sources": {
#       "Tripulantes (Flight Attendants)": "The source \"tripulantes\" refers to flight attendants. They provide information about their concerns and practices during the pandemic, such as leaving food trays on an intermediate seat between them and the passenger, and wanting concrete measures to avoid contagion.",
#       "Precios de los billetes (Ticket Prices)": "The source \"precios de los billetes\" refers to ticket prices. They provide information about the potential need to increase ticket prices to compensate for the impact of the pandemic on the airline industry.",
#       "Comandante (Pilot)": "The source \"comandante\" refers to a pilot. They provide information about their role in ensuring passenger safety, such as asking passengers not to exit the aisle until all passengers in front of them have disembarked.",
#       "Las aerolineas (Airlines)": "The source \"las aerolineas\" refers to airlines in general. They provide information about their preparations for a return to normal operations, including potentially maintaining social distancing measures and reducing passenger capacity.",
#       "La estadounidense Delta (Delta Airlines)": "The source \"la estadounidense Delta\" refers to Delta Airlines. They provide information about their specific measures to combat the pandemic, including blocking middle seats, reducing passenger capacity, and optimizing food service.",
#       "Stephen Trent (Analyst)": "The source \"Stephen Trent\" refers to an analyst at Citigroup. He provides information about the potential benefits of removing middle seats on planes and the possibility of airlines being required to do so.",
#       "Jozsef Varadi (Wizz Air CEO)": "The source \"Jozsef Varadi\" refers to the CEO of Wizz Air. He provides information about his airline's plans to limit passenger capacity to two-thirds of the plane's capacity.",
#       "Medidas (Measures)": "The source \"medidas\" refers to general measures being taken by airlines. They provide information about the varying approaches taken by different airlines to combat the pandemic.",
#       "San Felix": "The source \"San Felix\" provides information about the potential challenges and costs of reducing passenger capacity, including the need for higher ticket prices or government subsidies.",
#       "Various Airlines": "The source \"varias aerolineas\" refers to multiple airlines operating in Spain. They provide information about their reluctance to take measures to reduce passenger capacity and their concerns about the potential impact on their business.}"
#     }
#   },
#   {
#     "article_url": "www.usatoday.com/story/news/nation/2021/10/04/covid-mask-enforcement-women-bear-burden-backlash/5924477001/",
#     "Sources": {
#       "Linda Sanchez": "Linda Sanchez is a server and assistant manager at Rockin' Baja Lobster restaurant. She provides personal anecdotes and experiences about enforcing mask mandates and dealing with hostile customers, including verbal abuse and lost tips.",
#       "Christine Williams": "Christine Williams is a University of Texas at Austin sociology professor who studies gender, race, and class inequities. She provides expert insights on how women-dominated positions have become the \"first line of defense\" when it comes to mask mandates and vaccine verification, and how this has led to a disproportionate burden on women in these roles.",
#       "Labor Activists": "Labor activists provide information on the burden and trauma faced by frontline service workers, particularly women, who are responsible for policing mask and vaccination policies. They highlight the power imbalance between workers and customers and the resulting hostility and trauma experienced by workers.",
#       "Research": "Research provides evidence on the prevalence of unruly and dangerous reactions, including sexual harassment and racism, towards frontline workers who enforce mask mandates. It also highlights the disproportionate impact of COVID-19 on women, including greater on-the-job health risks and job losses.",
#       "Meghna Sabharwal": "Meghna Sabharwal is a professor and department head in the Public and Nonprofit Management program at the University of Texas at Dallas. She provides expert insights on how women are more likely to experience sexual harassment and racism when enforcing mask mandates due to being perceived as the \"weaker sex\".",
#       "Clare Hammonds and Jasmine Kerrissey (monds and Jas)": "Clare Hammonds and Jasmine Kerrissey are University of Massachusetts Amherst behavioral scientists. They provide research findings on the prevalence of problems with compliance when frontline workers ask customers to follow mask rules, particularly in the hospitality and retail industries.",
#       "Nancy Wong": "Nancy Wong is a University of Wisconsin-Madison professor of consumer research and marketing. She provides expert insights on how the power differential between customers and employees is exacerbated by gender, leading to sexist bullying and harassment towards female employees who enforce mask mandates.",
#       "Gallup": "Gallup is a polling organization. It provides data on the percentage of women and men who always or often wear masks outside the home, showing a significant gender gap.",
#       "Academic Study": "An academic study provides research findings on how men are more likely to resist masks due to perceptions of shame, uncoolness, or weakness, and how this affects their behavior during the pandemic.",
#       "National Women's Law Center": "The National Women's Law Center provides data on the disproportionate impact of COVID-19 on women, including greater on-the-job health risks and job losses. It also highlights how women have been harmed by COVID-19 in the workforce.",
#       "Vyvianna Quinonez": "Vyvianna Quinonez is a passenger who was involved in an incident on a Southwest Airlines flight. She provides an example of a violent reaction towards a flight attendant who enforced mask mandates.",
#       "Federal Court Records": "Federal court records provide evidence of a violent incident on a Southwest Airlines flight, where a passenger punched a flight attendant in the mouth, causing her to lose two teeth.",
#       "Retail Industry Leaders Association": "The Retail Industry Leaders Association provides information on the alarming rate of hostility and violence towards frontline workers, leading to calls for governors to require shoppers to wear masks.",
#       "National Retail Federation": "The National Retail Federation provides information on the need for a national mask mandate to protect frontline workers from hostility and violence.",
#       "Businesses": "Businesses provide information on the varying COVID-19 requirements and rules that employees are expected to enforce, and the challenges they face in doing so.",
#       "Centers for Disease Control and Prevention": "The Centers for Disease Control and Prevention (CDC) provides guidance on how businesses and employees can avoid dangerous altercations when enforcing COVID-19 prevention policies.",
#       "Federal Data": "Federal data provides information on the demographics of the workforce, including the percentage of women in various industries such as flight attendants, registered nurses, and food servers.",
#       "Bureau of Labor Statistics": "The Bureau of Labor Statistics provides data on the demographics of the workforce, including the percentage of women in various industries such as retail and food service.",
#       "Alicia Grandey": "Alicia Grandey is a Penn State University professor of industrial-organizational psychology. She provides expert insights on the power imbalance between customers and employees, and how this affects the well-being of workers, particularly women, who enforce mask mandates.",
#       "Sara Nelson": "Sara Nelson is the president of the Association of Flight Attendants-CWA. She provides information on the prevalence of unruly passengers on flights, including those who resist mask mandates, and the impact on flight attendants' safety and well-being.",
#       "Delta Air Lines": "Delta Air Lines provides information on its efforts to address unruly passengers, including banning 1,600 passengers and urging competitors to collaborate on a no-fly list.",
#       "Joe Biden": "Joe Biden is the President of the United States. He provides a statement urging passengers to respect flight attendants and warning}"
#     }
#   },
#   {
#     "article_url": "www.nbcnews.com/tech/mobile/binge-t-mobile-adds-free-video-streaming-data-plans-n460896",
#     "Sources": {
#       "Netflix": "Netflix is a video streaming service. It provides informational content about its own service, specifically mentioning that it has 5-minute episodes to help with kid-bedtime negotiations, and referencing its popular show \"House of Cards\".",
#       "T-Mobile": "T-Mobile is a mobile network operator. It provides informational content about its new feature \"Binge On\", which allows customers to stream video from select partners without counting against their data limits. It also announces that it is doubling the amount of 4G LTE data offered on each plan without raising prices, and notes that YouTube is not a partner in the \"Binge On\" program.",
#       "John Legere": "John Legere is the CEO of T-Mobile. He provides a quote announcing the \"Binge On\" feature, taking a dig at competitors Verizon and AT&T, and emphasizing the benefits of the new feature for customers.\n\nNote: The source \"T-Mobile Adds Free Video Streaming to Data Plans by Keith Wagstaff Share Share Tweet Share Email Comment advertisement Facebook Twitter Google Plus Embed Netflix says new 5-minute episodes are to help kid-bedtime negotiations 1:08 autoplay autoplay Copy this code to your website or blog Can't stop binge-watching \\\"House of Cards?\\\" Now T-Mobile customers can stream all the video they want for free... well, except for YouTube videos. The service, titled \\\"Binge On,\\\" lets mobile users stream video from 24 services without having it counting against their data limits. The company's outspoken CEO, John Legere\" is actually a duplicate of the T-Mobile source, and has been grouped together with it.}"
#     }
#   },
#   {
#     "article_url": "www.ksdk.com/article/news/nation-world/delta-air-lines-flight-rebooking/507-fd82cd59-42f6-43c4-a5c7-0f19f790f3df",
#     "Sources": {
#       "Delta": "Delta is the airline company being reported on in the article. They provide informational content regarding their policies, operations, and statements. Specifically, they provide details on their rebooking policy, eCredit system, and travel credit extensions. They also offer quotes from their executives, such as Chief Customer Experience Officer Allison Ausband, and provide updates on their operation's stability following the holidays and omicron surge.",
#       "USA TODAY": "USA TODAY is a news organization that provides a report on Delta's announcement, stating that it's the first major U.S. airline to make the change. They contribute a single sentence to the article, providing context on Delta's announcement.",
#       "Allison Ausband": "Allison Ausband is the Chief Customer Experience Officer at Delta. She provides a quote in the article, stating that Delta wants to ensure customers have peace of mind when booking or rebooking their trips in 2022.",
#       "Ed Bastian": "Ed Bastian is the CEO of Delta. He provides information on the company's operation, addressing concerns over the omicron variant's impact on staffing and flight cancellations. He also updates on the company's current operation, stating that it has returned to \"pre-holiday performance.\"",
#       "11Alive staff": "11Alive staff is a news organization that contributed to the report, likely providing additional context or information to the article. However, their specific contribution is not clear from the annotations.",
#       "KSDK": "KSDK is a news organization that provides a notification to readers, asking if they would like to receive push notifications about the latest news and weather. They also provide information on how to turn off notifications in browser settings.",
#       "Journalist (passive voice)": "This source is likely the author of the article, using passive voice to provide general information or transitions between quotes and statements from other sources. They do not provide any specific information or quotes, but rather help to structure the article.}"
#     }
#   },
#   {
#     "article_url": "www.forbes.com/2010/12/13/generation-gen-y-2-leadership-managing-change.html",
#     "Sources": {
#       "James R. Flynn": "James R. Flynn is a sociologist who provides information about the changing expectations of Generation Y employees. He notes that this generation has grown up with instant gratification and has different attitudes towards work and technology. Flynn also discusses the Flynn effect, which suggests that human IQ increases by 10 points every 30 years due to better nutrition, education, and environmental complexity, making the youngest employees at least 10% smarter than their older colleagues.",
#       "Sangeeth Varghese": "Sangeeth Varghese is a leadership thinker and founder of LeadCap Ventures, a global market research and consulting firm. He provides information about the impact of technology on the workplace, noting that technologies like Facebook and Twitter have made gratification quicker than instant. He is also the author of a forthcoming book on open source leadership.",
#       "Cisco": "Cisco is a technology company that provides information about the changing expectations of employees in the digital age. According to a Cisco survey, three-quarters of respondents would take a job at less pay if it gave them more flexibility in their use of electronic devices, and two-thirds said companies should let them use social media on company time and company devices. Cisco also notes that the new generation has grown up in a time when information and access to it are truly democratized, forcing companies to change the way they manage.",
#       "Journalist": "The journalist is the author of the article and provides general commentary and analysis on the changing expectations of Generation Y employees. They note that the new generation has different attitudes towards work and technology, and that these attitudes would have seemed outrageous just a few years ago. They also provide examples of how companies are adapting to these changes, such as HCL Technologies' promotion of intrapreneurship.",
#       "Open-source software": "Open-source software is a concept that provides information about the phenomenon of \"forkability,\" where programmers can \"fork\" away from a project if they are dissatisfied with it and start a new project entirely on their own. This concept is used as an analogy to describe the changing expectations of employees in the digital age.",
#       "Sergi Inko": "Sergi Inko is a champion of open-source software who provides an analogy to describe the changing expectations of employees in the digital age. He notes that in a world where employees can easily \"fork\" away from a company and start their own ventures, companies must adapt to these new expectations in order to retain talent.",
#       "HCL Technologies": "HCL Technologies is a company that provides information about its approach to managing the changing expectations of Generation Y employees. The company promotes \"intrapreneurship,\" allowing employees to pursue projects of their own choice and providing them with the freedom to engage in their real interests.}"
#     }
#   },
#   {
#     "article_url": "www.usatoday.com/story/travel/airline-news/2020/06/03/delta-block-middle-seats-through-september-amid-coronavirus/3136273001/",
#     "Sources": {
#       "Delta": "Delta is the airline company. They provide informational content about their policies and actions regarding COVID-19 measures, including blocking middle seats, capping seating, and requiring passengers and crew members to wear masks or face coverings.",
#       "Bill Lentsch": "Bill Lentsch is the chief customer experience officer at Delta Air Lines. He provides a statement explaining the importance of reducing the number of customers on each aircraft to ensure a safe experience for customers and employees.",
#       "Delta Air Lines (combined)": "This source combines annotations from \"Delta Air Lines\" and \"Delta commits to blocking middle seats through the summer to stem spread of coronavirus Julia Thompson USA TODAY Delta\". Delta Air Lines provides informational content about their policies and actions regarding COVID-19 measures, including blocking middle seats, capping seating, and requiring passengers and crew members to wear masks or face coverings.",
#       "Executives": "Executives are unnamed airline executives. They provide insight into the temporary nature of social distancing measures in the airline industry, citing financial concerns if such measures were to be made permanent.",
#       "JetBlue": "JetBlue is an airline company. They provide informational content about their policy of blocking middle seats in certain situations through July 6.",
#       "Ross Feinstein": "Ross Feinstein is a spokesman for American Airlines. He provides statements about American Airlines' policies and actions regarding COVID-19 measures, including limiting the number of customers on each aircraft and notifying customers about full flights.",
#       "Southwest": "Southwest is an airline company. They provide informational content about their policy of keeping middle seats open through at least July 31.",
#       "United Airlines": "United Airlines is an airline company. They provide informational content about their policy of notifying passengers 24 hours before their flight if it is expected to be more than 70% full.}"
#     }
#   },
#   {
#     "article_url": "www.slate.com/articles/news_and_politics/politics/2014/03/at_t_verizon_t_mobile_sprint_and_auctioning_airwaves_the_corporate_giants.html",
#     "Sources": {
#       "Slate's Terms of Service and Privacy Policy": "This source is the official terms of service and privacy policy of Slate, a media organization. It provides informational content about how Slate uses data, including the use of technologies such as cookies, to deliver personalized advertising and perform site analytics on their iOS app.",
#       "Privacy Policy": "This source is the same as Slate's Terms of Service and Privacy Policy, and is likely a reference to the same document. It provides additional information about Slate's use of data, including users' rights and how to withdraw consent.}"
#     }
#   },
#   {
#     "article_url": "www.huffpost.com/entry/mike-huckabee-asian-hate-crime-vote-supression-racist-tweet_n_606915ddc5b66c4ab6b361d5",
#     "Sources": {
#       "BuzzFeed": "BuzzFeed is the publisher of the article. They provide the copyright information at the beginning and end of the article, indicating that they own the rights to the content.",
#       "Mike Huckabee": "Mike Huckabee is a former Arkansas Governor and Republican. He provides several tweets and statements that are quoted in the article, including a dismissive and mocking tweet about people of Chinese ancestry in America, as well as responses to criticism from others. His tweets and statements are the central focus of the article.",
#       "Coca-Cola": "Coca-Cola is a corporation headquartered in Atlanta, Georgia. They provide information about their stance against Georgia's new voting law, with their CEO stating that the law does not match the company's values.",
#       "Ed Bastian": "Ed Bastian is the CEO of Delta Airlines. He provides a statement to employees about Delta's opposition to Georgia's new voting law, calling it a \"lie\" and stating that it does not match the company's values.",
#       "Rob Manfred": "Rob Manfred is the Commissioner of Major League Baseball. He provides a statement announcing that MLB is moving its 2021 All-Star Game out of Atlanta to protest Georgia's new voting law, citing the league's support for voting rights for all Americans.",
#       "Center for the Study of Hate and Extremism at California State University": "The Center for the Study of Hate and Extremism at California State University is a research organization. They provide data and statistics about the surge in hate crimes against Asian Americans, including a 150% increase in hate crimes in America's largest cities last year.",
#       "Xiao Zhen Xie": "Xiao Zhen Xie is a 78-year-old Chinese American woman who was punched in the face in San Francisco. Her experience is cited as an example of the surge in hate crimes against Asian Americans.",
#       "Beth Moore": "Beth Moore is a Bible teacher. She provides a statement challenging Mike Huckabee's tweet, calling it \"antithetical to the gospel.\" She also describes a violent attack on a 65-year-old Asian American woman in Manhattan.",
#       "New Georgia Project": "The New Georgia Project is an organization. They provide a tweet responding to Mike Huckabee's tweet, calling him a \"raging bigot.\"}"
#     }
#   },
#   {
#     "article_url": "www.politico.com/newsletters/morning-tech/2022/01/19/5gs-turbulent-takeoff-799942",
#     "Sources": {
#       "@PoliticoPro": "@PoliticoPro is a news organization that provides information on politics and policy. In this article, they provide a promotional message encouraging readers to follow them on Twitter and subscribe to their newsletter.",
#       "Air India": "Air India is an airline company that provides information on flight cancellations due to the rollout of 5G wireless service.",
#       "All Nippon Airways' CEO": "The CEO of All Nippon Airways is a representative of the airline company that provides information on flight cancellations and apologies for the inconvenience caused by the 5G rollout.",
#       "Andrew Ross Sorkin": "Andrew Ross Sorkin is a CNBC co-anchor who provides information on an upcoming interview with FTC Chair Lina Khan.",
#       "Anna Eshoo": "Anna Eshoo is a Democratic Representative from California who provides information on a new bill aimed at cracking down on targeted ads and her views on the gaming industry.",
#       "Ajit Pai": "Ajit Pai is the former FCC chair under President Donald Trump who provides information on the FCC's analysis of 5G safety concerns.",
#       "Biden administration": "The Biden administration provides information on their efforts to regulate the tech industry, including antitrust legislation and 5G rollout.",
#       "Bloomberg": "Bloomberg is a news organization that provides information on the White House's meeting to discuss supporting Senate antitrust legislation.",
#       "Brendan Carr": "Brendan Carr is a GOP Commissioner who provides information on his views on the White House's handling of 5G rollout and antitrust legislation.",
#       "CNBC": "CNBC is a news organization that provides information on an upcoming interview with FTC Chair Lina Khan.",
#       "Congress": "Congress provides information on their efforts to regulate the tech industry, including antitrust legislation and targeted ads.",
#       "Congressional Hispanic Caucus members": "Congressional Hispanic Caucus members provide information on their efforts to address Spanish-language misinformation on social media platforms.",
#       "Create": "Create is an organization that provides information on the creator economy and the importance of internet access for digital entrepreneurs and small businesses.",
#       "Doha Mekki": "Doha Mekki is a principal deputy assistant attorney general for antitrust who provides information on her promotion to the role.",
#       "Epic": "Epic is a gaming company that provides information on their views on the gaming industry and antitrust legislation.",
#       "FCC": "The Federal Communications Commission (FCC) provides information on their analysis of 5G safety concerns and their role in regulating the tech industry.",
#       "Jan Schakowsky": "Jan Schakowsky is a Democratic Representative from Illinois who provides information on her views on targeted ads, antitrust legislation, and her efforts to regulate the tech industry.",
#       "Jessica Rosenworcel": "Jessica Rosenworcel is the FCC chair who provides information on her views on 5G rollout and its economic significance.",
#       "Joe Biden": "Joe Biden is the President of the United States who provides information on his administration's efforts to regulate the tech industry and the 5G rollout.",
#       "John Hendel": "John Hendel is a journalist who provides information on his coverage areas, including broadband access, net neutrality, and 5G wireless technology.",
#       "Ken Buck": "Ken Buck is a Republican Representative from Colorado who provides information on his views on Microsoft's acquisition of Activision-Blizzard.",
#       "Lawmakers": "Lawmakers provide information on their efforts to regulate the tech industry, including antitrust legislation and targeted ads.",
#       "Lina Khan": "Lina Khan is the FTC chair who provides information on her views on antitrust legislation and her upcoming interview with CNBC.",
#       "MetroNews": "MetroNews is a news organization that provides information on a senator's efforts to gather information on internet connectivity in her state.",
#       "Microsoft": "Microsoft is a technology company that provides information on their acquisition of Activision-Blizzard and their views on the gaming industry.",
#       "Morning Tech": "Morning Tech is a newsletter that provides information on the latest news in technology politics and policy.",
#       "Peter DeFazio": "Peter DeFazio is a Democratic Representative from Oregon who provides information on his views on 5G rollout and its impact on aviation safety.",
#       "Politico": "Politico is a news organization that provides information on politics and policy, including the tech industry.",
#       "Re": "Re is an organization that provides information on the creator economy and the importance of internet access for digital entrepreneurs and small businesses.",
#       "Republican leaders": "Republican leaders provide information on their views on the White House's handling of 5G rollout and antitrust legislation.",
#       "The Information": "The Information is a news organization that provides information on the tech industry, including Microsoft's acquisition of Activision-Blizzard.",
#       "Tom Power": "Tom Power is the general counsel for wireless trade group CTIA who provides information on his views on 5G rollout and its impact on the tech industry.",
#       "Washington Post": "The Washington Post is a news organization that provides information on the NTIA's broadband buildout mandate and its potential impact on the tech industry.",
#       "White House": "The White House provides information on their efforts to regulate}\n\nfortune.com/2022/04/02/delta-air-lines-terminal-lax-los-angeles-international-airport/\n{Here are the summaries for each source:",
#       "Delta Air Lines": "Delta Air Lines is the primary source of information in this article. They provide details about their new facilities, investments, and projects, including the unveiling of three new facilities at LAX, LGA, and SEA airports. They also share information about their current operations, such as the number of daily flights and employees at LAX, as well as their sustainability features, including LEED Silver Certification and facial recognition technology. Additionally, they provide information about their premium amenities, including the new Sky Club and its features.",
#       "Fortune": "Fortune is a secondary source that provides information about Delta Air Lines' ranking on the Fortune 500 list and its position among the World's Most Admired Companies in 2021. They also provide general information about the Fortune brand, including their terms of use, privacy policy, and trademark information.",
#       "Frequent Flyers": "Frequent flyers are a source of anecdotal information, providing personal experiences and observations about the current state of Terminal 2 at LAX, including its cramped conditions during peak hours and the outdated nature of the previous Terminal 3.",
#       "Journalist": "The journalist is a passive-voice source that provides some background information about the history of Terminal 3 at LAX, including its previous occupants and the impact of Delta's move to Terminals 2 and 3.",
#       "Fortune Media IP Limited": "Fortune Media IP Limited is a source that provides information about their brand, including their terms of use, privacy policy, and trademark information. They also disclose that they may receive compensation for some links to products and services on their website.",
#       "Chicago Mercantile Exchange": "The Chicago Mercantile Exchange is a source that provides information about their index data and its ownership. They also provide a disclaimer about offers being subject to change without notice.",
#       "Interactive Data Managed Solutions": "Interactive Data Managed Solutions is a source that provides information about their role in powering and implementing the website's data solutions.}"
#     }
#   },
#   {
#     "article_url": "www.upi.com/Top_News/US/2018/08/02/Cisco-to-pay-235B-for-data-security-firm-Duo/7361533224779/",
#     "Sources": {
#       "Duo Security": "Duo Security is a company that provides a platform for verifying user identities and device health. The informational content they provide to the article is a description of their product and its functionality, specifically that it helps companies fend off data breaches.",
#       "Cisco": "Cisco is a company that has acquired Duo Security. The informational content they provide to the article includes details about the acquisition, such as the expected closing date, the benefits of the acquisition, and how it will extend their security capabilities. They also provide context about their previous acquisitions and their focus on security innovation.",
#       "David Goeckeler": "David Goeckeler is an executive vice president at Cisco. The informational content he provides to the article includes quotes about the complexity of IT security and how the acquisition of Duo Security will help address these challenges. He also explains how Duo's products will integrate with Cisco's platforms to provide better security for customers.",
#       "Chuck Robbins": "Chuck Robbins is the CEO of Cisco. The informational content he provides to the article is a quote about Cisco's focus on security innovation, specifically in complex data centers.",
#       "Michael Flynn": "Michael Flynn is a former national security advisor. The informational content he provides to the article is a news update about his request to withdraw his guilty plea, which is unrelated to the main topic of the article.",
#       "U.S. News": "U.S. News is a news organization. The informational content they provide to the article is two unrelated news updates, one about Michael Flynn's request to withdraw his guilty plea and another about a Wisconsin appeals court blocking the purge of 200,000 voters from the state's voter rolls.}"
#     }
#   },
#   {
#     "article_url": "www.newsmax.com/newsfront/delta-airlines-pit-bulls-airline-safety-support-animals/2018/06/21/id/867580/",
#     "Sources": {
#       "CBS News": "CBS News is a news organization that provides information on current events. In this article, CBS News provides the specific date of when the policy goes into effect, which is July 10.",
#       "Delta": "Delta is an airline company that provides information about its policies and incidents related to service animals. In this article, Delta provides information about the reason behind the policy update, which is due to growing safety concerns following recent incidents of employees being bitten by service animals. They also provide specific details about past incidents, such as the high-profile incident in Atlanta in 2017 and the recent incident where two employees were bitten by a customer's dog. Additionally, Delta provides information about its previous policy update in January, which tightened the rules on bringing emotional support animals into airplane cabins.",
#       "Incidents": "Incidents is a source that provides information about past events related to service animals. In this article, Incidents provides a general statement about multiple incidents of service dogs biting passengers and airline employees at airports in recent years.",
#       "Gil West": "Gil West is the COO of Delta Airlines. In this article, Gil West provides a statement about Delta's priority, which is to keep passengers and employees safe. He also mentions that Delta will continue to review and enhance its policies and procedures to ensure safety.",
#       "Newsmax Comment": "Newsmax Comment is a source that provides information about comment policies. In this article, Newsmax Comment provides a statement about keeping discussions on topic and avoiding personal attacks and threats.",
#       "Pope Francis": "Pope Francis is the head of the Catholic Church. In this article, Pope Francis provides a statement about countries taking in as many refugees as they can integrate into their societies.",
#       "Passive-voice": "Passive-voice is a source that provides information about news events. In this article, Passive-voice provides information about US military aircraft being shined with lasers from Chinese fishing boats.",
#       "Trump": "Trump is the President of the United States. In this article, Trump provides a statement about signing something related to detained children.}"
#     }
#   },
#   {
#     "article_url": "www.forbes.com/sites/douggollan/2019/12/14/deltas-ed-bastian-may-just-have-become-the-most-important-person-in-business-aviation/",
#     "Sources": {
#       "TSA": "The source is the Transportation Security Administration (TSA). They provide information about the recent steps taken to combat lengthy security lines at airports, including investing in personnel.",
#       "Delta": "The source is Delta Air Lines. They provide information about the \"innovation lanes\" they introduced at Hartsfield-Jackson Atlanta International Airport, including the cost of implementing the technology and the increased screening rate.",
#       "Morgan Durrant": "The source is Morgan Durrant, a spokesman for Delta Air Lines. He provides information about the features and benefits of the \"innovation lanes\", including the automated bin system, separate area for flagged items, and increased screening rate.",
#       "Experts": "The source is a group of unnamed experts. They provide an opinion that the money spent on combating security lines could be better spent on improving technology used to screen passengers and their luggage.",
#       "Innovation Lanes": "The source is the \"Innovation Lanes\" program. They provide information about the new security lanes introduced at Hartsfield-Jackson Atlanta International Airport, including their ability to clear passengers at a quicker rate than standard lanes.",
#       "Analogic": "The source is Analogic, a company that provides 3D scanning technology. They provide information about their COBRA machines, which can automatically detect security threats or illegal substances in bags, and can screen luggage at a faster rate than traditional scanners.",
#       "Green": "The source is Green, likely an employee or representative of Analogic. They provide information about the capabilities and benefits of the COBRA machines, including their ability to double the amount of luggage screened per hour.",
#       "Engineers": "The source is a team of engineers at Northeastern University. They provide information about their project to develop a walk-through screening technology that can quickly screen multiple passengers at a time and detect potential threats.",
#       "Jose Martinez": "The source is Jose Martinez, an engineering professor at Northeastern University leading the walk-through screening project. He provides information about the project's goals, potential benefits, and timeline, including the potential to triple the current screen rate to 300 passengers per hour.",
#       "Privacy Policy": "The source is the website's Privacy Policy. They provide a notification about changes to the Terms of Service and Privacy Policy, and inform users that continued use of the site constitutes agreement to the new policies.",
#       "OffersPaid": "The source is OffersPaid, a partner offering credit card promotions. They provide a promotional message about top credit cards for those with excellent credit.}"
#     }
#   },
#   {
#     "article_url": "www.dailymail.co.uk/news/article-5275589/Marriott-remove-banned-book-avoid-China-backlash.html",
#     "Sources": {}
#   },
#   {
#     "article_url": "www.cnn.com/2000/TECH/computing/04/14/wireless.boom.idg/index.html",
#     "Sources": {
#       "Internet Archive": "The Internet Archive is a 501(c)(3) non-profit organization. They provide informational content about their own initiatives and policies, including the fact that they are building a digital library of Internet sites and other cultural artifacts, and that they have terms of use for the Wayback Machine. They also express their commitment to fighting for all libraries.",
#       "Open Library & archive-it.org": "Open Library and archive-it.org are projects related to the Internet Archive. They provide information about other projects related to the Internet Archive, specifically mentioning Open Library and archive-it.org as examples.}\n\nfortune.com/2021/12/27/airlines-flights-canceled-omicron-pilots-flight-attendants/\n{Here are the summaries for each source:",
#       "FlightAware": "FlightAware is a flight tracking service. They provide information on flight delays and cancellations, including the number of delayed and canceled flights globally on a specific day, as well as real-time updates on flight status.",
#       "Delta Air Lines": "Delta Air Lines is an airline company. They provide information about their response to the incident, including the fact that they are issuing a travel waiver to assist impacted customers.",
#       "John Laughter": "John Laughter is the operations chief at Delta Air Lines. He provides a quote explaining the reasons behind Delta's operational issues, citing a \"perfect storm\" of weather systems and the Omicron surge.",
#       "United": "United is a major airline. They provide information on their own flight operations, including the percentage of flights delayed or canceled due to staff shortages caused by the Omicron variant.",
#       "JetBlue spokesperson": "The JetBlue spokesperson represents JetBlue, a major airline. They provide information on JetBlue's preparedness for the holiday travel surge and the impact of Omicron-related sick calls on their flight operations.",
#       "Department of Transportation": "The Department of Transportation is a government agency. They provide historical data on flight cancellations, specifically the percentage of flights canceled by major carriers in 2019.",
#       "Bryan Quigley": "Bryan Quigley is United's senior vice president of flight operations. He provides information on the impact of the Omicron surge on United's pilot staff, including the rising number of COVID-19 cases and pilots in quarantine.",
#       "International Air Transport Association": "The International Air Transport Association is a trade association representing airlines. They provide information on the industry's request to the CDC to shorten quarantine guidelines for fully vaccinated individuals who test positive for COVID-19.",
#       "Nicholas Calio": "Nicholas Calio is the CEO of Airlines for America, a trade association representing major airlines. He provides a quote explaining the potential impact of the Omicron surge on airline operations and workforce.",
#       "Centers for Disease Control and Prevention": "The Centers for Disease Control and Prevention (CDC) is a government health agency. They provide information on the prevalence of the Omicron variant, including the percentage of cases in the US, as well as guidance on quarantine guidelines.",
#       "Major airlines": "Major airlines are a group of airlines. They provide information on the safety measures in place on their planes, including hospital-grade filtration systems.",
#       "David Powell": "David Powell is a physician and medical adviser to the International Air Transport Association. He provides information on the contagiousness of the Omicron variant and its impact on the risk of getting sick on planes.",
#       "Fortune Media IP Limited": "Fortune Media IP Limited is the publisher of the article. They provide information on their terms of use, privacy policy, and other legal notices.",
#       "Interactive Data Managed Solutions": "Interactive Data Managed Solutions is a technology provider. They power and implement the website's data management solutions.",
#       "Chicago Mercantile Exchange Inc.": "Chicago Mercantile Exchange Inc. is a financial exchange. They own the rights to S&P Index data used on the website.",
#       "S&": "S& is an unknown entity. They provide a notice that offers may be subject to change without notice.}\n\nthehill.com/blogs/ballot-box/311446-delta-airlines-youtube-star-kicked-off-flight-for-shouting-not-for-speaking/\n{Here are the summaries for each source:",
#       "Airline": "The source is the airline, specifically Delta. This source provides information about the incident, including the reason for Adam Saleh's removal from the flight, the debriefing of the crew, and the collection of passenger statements. The airline also provides a statement about their priority being the safety and comfort of their passengers and employees.",
#       "Adam Saleh": "The source is Adam Saleh, a YouTube personality. This source provides personal accounts and reactions to the incident, including a video he posted on social media, in which he claims he was kicked off the flight for speaking Arabic to his mother. He also provides context about his past controversies, including a previous viral video that was later debunked.",
#       "Media Reports": "The source is media reports, which provide additional context about Adam Saleh's past behavior, specifically that one of the individuals removed from the flight is a known prankster who was video recorded and encouraged by his traveling companion.",
#       "Putin": "The source is Putin, but it appears to be an error in annotation, as the sentence provided does not relate to the rest of the article. It seems to be a collection of unrelated news headlines.}\n\nkvia.com/news/us-world/cnn-national/2021/11/20/departing-planes-halted-after-accidental-discharge-at-atlanta-airport-officials-say/\n{Here are the summaries for each source:",
#       "Robert Spinden": "Robert Spinden is the Transportation Security Administration's federal security director for Georgia. He provides information about the incident, including the details of the security checkpoint process, the passenger's actions, and the consequences of the firearm discharge. He also expresses relief that no one was seriously injured.",
#       "Transportation Security Administration (TSA)": "The Transportation Security Administration (TSA) is a government agency responsible for airport security. The TSA provides information about the incident, including the number of people injured and the fact that firearms are not allowed in carry-on bags. They also provide context about the frequency of firearms being found at airport checkpoints and the importance of checking personal belongings for dangerous items.",
#       "Atlanta Police": "Atlanta Police is the law enforcement agency responsible for the Atlanta airport. They provide information about the incident, including the fact that no injuries were initially reported.",
#       "Source": "The \"source\" is an unnamed individual familiar with the situation. This source provides additional details about the incident, including the fact that the injured were not shot but hurt during the evacuation, and that the discharged round went into the property of the person who brought the weapon.",
#       "Reginald L. Moorman": "Reginald L. Moorman is the Atlanta Police Department Airport Precinct Commander. He provides information about the individual whose weapon was discharged, including the person's identity and the charges they face.",
#       "Andrew Gobeil": "Andrew Gobeil is an airport spokesperson. He provides information about the incident, including the fact that the discharge was accidental and that airport officials and Atlanta Police know who the individual is. He also mentions that an investigation is ongoing.",
#       "Erika Zeidler": "Erika Zeidler is a passenger who witnessed the incident. She provides a firsthand account of what she saw and heard during the incident, including people running and screaming.",
#       "Airport Officials": "Airport Officials are responsible for managing the airport. They provide information about the incident, including the fact that there is no danger to passengers or employees and that the airport is resuming normal operations.",
#       "Federal Aviation Administration (FAA)": "The Federal Aviation Administration (FAA) is a government agency responsible for aviation safety. They provide information about the incident, including the fact that a ground stop was called for the airport.",
#       "ATF": "The ATF (Bureau of Alcohol, Tobacco, Firearms and Explosives) is a government agency responsible for investigating firearms incidents. They provide information about their role in the investigation, including the fact that they are providing investigative assistance to the Atlanta police.",
#       "White House Official": "A White House Official is a representative of the White House. They provide information about the White House's response to the incident, including the fact that they are monitoring the situation.",
#       "Witnesses": "Witnesses are passengers who witnessed the incident. They provide firsthand accounts of what they saw and heard during the incident, including chaos and panic.",
#       "TSA Spokesperson": "A TSA Spokesperson is a representative of the Transportation Security Administration. They provide information about the number of airport travelers screened on the day of the incident.",
#       "Hasmet Asilkan": "Hasmet Asilkan is a passenger who witnessed the incident. He provides a firsthand account of what he saw and heard during the incident, including people running out of the airport.",
#       "Stephon Stafford": "Stephon Stafford is a passenger who witnessed the incident. He provides a firsthand account of what he saw and heard during the incident, including disorder inside the airport.",
#       "Greg Romero": "Greg Romero is a passenger who witnessed the incident. He provides a firsthand account of what he saw and heard during the incident, including airport personnel trying to keep people calm.",
#       "Dianne Callahan": "Dianne Callahan is a passenger who witnessed the incident. She provides a firsthand account of what she saw and heard during the incident, including screams and sirens.",
#       "David Pekoske": "David Pekoske is the TSA Administrator. He provides information about the frequency of firearms being found at airport checkpoints and the importance of checking personal belongings for dangerous items.",
#       "Page Pate": "Page Pate is a Georgia criminal defense attorney and constitutional lawyer. He provides information about the legal implications of bringing a firearm to an airport, including the potential fines and criminal prosecution.",
#       "Pamela Brown": "Pamela Brown is a CNN journalist. She provides information about the incident, including quotes from Page Pate.",
# ...
#       "Ed Bastian": "Ed Bastian is the CEO of Delta Air Lines. In this article, he provides his expectations for the airline industry, stating that travel rates will remain low in early 2021 but that the company will achieve positive cash flow by the spring.",
#       "Ipsos-Axios": "Ipsos-Axios is a polling and research firm. In this article, they provide data on travel trends, including the number of people traveling daily, as well as polling results on people's behavior and attitudes towards the pandemic, such as increasing optimism that the end of the pandemic is in sight.",
#       "Clayton Reid": "Clayton Reid is the CEO of travel marketing firm MMGY Global. In this article, he provides insight into travel trends, stating that travelers move quickly when they see positive news and optics that permit travel, and that demand will continue to rise as the news and narrative turns more positive.",
#       "Passive-Voice": "The passive-voice source appears to be the author of the article or an unknown source. In this article, they provide general information on the rise in vaccination rates and the steady increase in travel, dining, and other activities outside of the home.",
#       "Healthcare": "The Healthcare source appears to be a category or section of the publication rather than a specific person or organization. In this article, they provide a label or tag for the article, indicating that it falls under the category of healthcare news.",
#       "Dan Bishop": "Dan Bishop is a US Representative. In this article, he expresses his opinion on the nomination of a candidate to lead the Department of Health and Human Services, stating that Americans expected a qualified candidate who could expedite vaccine distribution and help defeat COVID-19.",
#       "Joe Biden": "Joe Biden is the President of the United States. In this article, he is mentioned as having made a campaign promise to be a centrist, unifying leader.",
#       "Jake Dima": "Jake Dima is a journalist or author. In this article, he provides news reports on various topics, including Russia recalling its ambassador to the US, a Florida man being arrested for attacking officers with a fire extinguisher during the Capitol siege, and a man pleading guilty to a misdemeanor over an anti-Trump flag dispute.",
#       "Kaelan Deese": "Kaelan Deese is a journalist or author. In this article, he provides a news report on Florida lawmakers signaling that they will not support Medicaid expansion for 800,000 residents despite the lower cost provided under the recently signed COVID-19 relief package.",
#       "Kevin Bessler": "Kevin Bessler is a journalist or author. In this article, he provides a news report on legislation to replace the state's lead service lines, which could cost up to $14 billion.",
#       "House Republicans": "House Republicans are a group of Republican members of the US House of Representatives. In this article, they are mentioned as asking the Department of Justice to probe whether Gov. Andrew Cuomo's COVID-19 policies violate the civil rights of individuals living in group homes, and as opposing medals to Capitol Police for actions during the Jan. 6 riots.",
#       "North Carolina Senate": "The North Carolina Senate is the upper chamber of the North Carolina General Assembly. In this article, they are mentioned as considering a bill that would allow state residents with concealed carry permits to legally carry guns at places of worship that share property with private schools.",
#       "Greg Bishop": "Greg Bishop is a journalist or author. In this article, he provides a news report on the cost of COVID-19 saliva testing for Illinois state Senators, staff members, and journalists.",
#       "Benjamin Yount": "Benjamin Yount is a journalist or author. In this article, he provides a news report on Wisconsin Assembly speaker suggesting that he supports requiring people to look for work before getting jobless benefits.",
#       "Spokesman": "The spokesman source appears to be an unnamed representative of an organization or individual. In this article, they provide information on former President Donald Trump being the \"}"
#     }
#   },
#   {
#     "article_url": "www.dailymail.co.uk/news/article-4925636/Delta-offer-FREE-Wi-Fi-text-messaging-flights.html",
#     "Sources": {}
#   },
#   {
#     "article_url": "www.thestreet.com/phildavis/news/mlbs-decision-to-drop-atlanta-highlights-the-economic-power-companies-can-wield-over-lawmakers-when-they-choose-to",
#     "Sources": {
#       "Benjamin Means": "Benjamin Means is a corporate governance scholar and University of South Carolina professor. He provides informational content on the power dynamics between corporations and lawmakers, including how corporations use their economic power to influence lawmakers, the nature of corporate power, and the potential impact of corporate boycotts on policy changes. He also offers insights on the motivations behind MLB's decision to move the All-Star Game and the potential actions that companies like Delta and Coca-Cola could take to make a difference on the voting rights issue.",
#       "Major League Baseball (MLB)": "Major League Baseball (MLB) is a professional sports organization. It provides informational content on its decision to move the 2021 All-Star Game from Atlanta to Denver in response to Georgia's new restrictive voting law, as well as its recent commitment to have zero tolerance for racial injustice.",
#       "Delta Air Lines": "Delta Air Lines is an airline company. It provides informational content on its reaction to Georgia's new restrictive voting law, including its public denouncement of the law and its potential leverage as a major employer in the state.",
#       "Republicans": "Republicans are a political party. They provide informational content on their reaction to MLB's decision to move the All-Star Game, including their vow to boycott baseball and the products of companies that denounce the voting law.",
#       "Companies": "Companies are general corporate entities. They provide informational content on how they use their economic power to get what they want from lawmakers, including the jobs and tax revenue they can provide or withhold.",
#       "Tesla": "Tesla is an electric vehicle and clean energy company. It provides informational content on its agreement to build a factory in Nevada in exchange for state benefits.",
#       "National Football League (NFL) teams": "National Football League (NFL) teams are professional sports organizations. They provide informational content on their negotiations with cities and states, including their demands for hefty taxpayer subsidies for new stadiums.",
#       "Team owners": "Team owners are individuals or entities that own sports teams. They provide informational content on their ability to extract hundreds of millions of dollars in new benefits from cities and states by threatening to move their teams.",
#       "State lawmakers": "State lawmakers are elected officials who make laws at the state level. They provide informational content on their desire to attract business investment and keep it, and how they cater to corporations to achieve this goal.",
#       "Hartford": "Hartford is a city in Connecticut. It provides informational content on the negative economic impact of corporations leaving a city, including stagnant property values and plunging tax revenue.",
#       "Mike Pence": "Mike Pence is a politician who served as Governor of Indiana. He provides informational content on his decision to support changing an Indiana law that would have allowed anti-gay discrimination in the name of religious freedom due to corporate pressure.",
#       "Georgia's governor": "Georgia's governor is the elected official who governs the state of Georgia. He provides informational content on his decision to veto a bill that would have legalized discrimination against same-sex couples on religious grounds due to corporate pressure.",
#       "South Carolina": "South Carolina is a state in the United States. It provides informational content on the partial repeal of a law that targeted transgender people due to corporate pressure.",
#       "Passive-voice": "Passive-voice is not a specific source, but rather a writing style. It provides informational content on the fact that boycotts did not end efforts to restrict LGBTQ rights at the state level, but demonstrated the economic and political pressure that corporations can exert to advance social causes.",
#       "Journalist": "The journalist is the author of the article. They provide informational content on the overall narrative and analysis of the article, including the question of what it would take for companies to leave Georgia and the potential impact of corporate boycotts on policy changes.",
#       "Will Smith's production company": "Will Smith's production company is a film production company owned by actor Will Smith. It provides informational content on its decision to pull its upcoming slavery-era drama, \"Emancipation,\" out of Georgia due to the voting law.",
#       "NCAA": "NCAA (National Collegiate Athletic Association) is a college athletics organization. It provides informational content on its decision to withhold championship games from South Carolina for 15 years until the state removed the Confederate flag from the Statehouse grounds.}"
#     }
#   },
#   {
#     "article_url": "www.huffpost.com/entry/black-friday-cyber-monday-apple-watch-deals-2018-series-4_n_5bf1af1be4b07573881f7383",
#     "Sources": {
#       "HuffPost News": "HuffPost News is the publisher of the article, and they provide the introductory content, including the title and the general theme of the article, which is about finding deals on Apple Watches during Black Friday and Cyber Monday.",
#       "Passive-voice": "The passive-voice source provides general information about the Apple Watch Series 4, its features, and its price tag. They also mention the availability of deals on earlier Apple Watch models.",
#       "Verizon": "Verizon is a telecommunications company that provides information about their promotions and deals on Apple Watches, including a discount on the first month of service and a discount on iPhone purchases when buying a new Series 4 Apple Watch.",
#       "Target": "Target is a retail company that provides information about their promotions and deals on Apple Watches, including a discount on the Series 3 Apple Watch and a bundle deal that includes an extra band.",
#       "Walmart": "Walmart is a retail company that provides information about their promotions and deals on Apple Watches, including a bundle deal that includes an extra band.",
#       "Black Friday deal sites": "Black Friday deal sites are a collection of websites that track and predict Black Friday deals. They provide information about predicted discounts on Apple Watches, including a direct discount on the Series 4.",
#       "Journalist": "The journalist is the author of the article and provides general information about the best spots to score Apple Watches during Black Friday and Cyber Monday, as well as a disclaimer about affiliate links.",
#       "Costco": "Costco is a retail company that provides information about their promotions and deals on Apple Watches, including a discount on the 42mm Series 3 GPS with a black sport band.",
#       "Macy's": "Macy's is a retail company that provides information about their promotions and deals on Apple Watches, including a discount on the Series 3 Apple Watch and a bonus offer of diamond cluster stud earrings with any purchase of $50 or more.",
#       "Groupon": "Groupon is a deal-of-the-day website that provides information about their Apple Watch options, including a deal on the Series 4 Apple Watch with wireless service from T-Mobile.}"
#     }
#   },
#   {
#     "article_url": "www.newsbusters.org/blogs/business/joseph-vazquez/2021/08/05/audio-mark-levin-slams-moral-frauds-woke-corporate-america",
#     "Sources": {
#       "The MRC": "The source is the Media Research Center (MRC), a research and education organization. It provides informational content about its own organization, specifically its tax-exempt status under Section 501(c)(3) of the Internal Revenue Code and the tax-deductibility of contributions to the MRC.",
#       "Levin": "The source is Mark Levin, a radio host. He provides quotes and opinions on various topics, including his criticism of corporate America's dealings with China, the NBA, and Lebron James, as well as his views on the Republican Party and the Communist Chinese government. He also provides commentary on the behavior of corporations and their boards.",
#       "Donate About Us Contact Us CONNECT": "The source appears to be a website or webpage, likely the MRC's website. It provides a list of menu items, including \"Free Speech\", \"Culture\", \"Business\", \"Latino\", \"Latest\", \"Donate\", \"About Us\", \"Contact Us\", and \"CONNECT\", as well as a call to sign up for the NB Daily newsletter.",
#       "Coca-Cola, Delta Air Lines": "The sources are Coca-Cola and Delta Air Lines, two U.S. corporations. They provide information about their actions, specifically their criticism of the Georgia voter integrity law.",
#       "Fox Business": "The source is Fox Business, a news organization. It provides a quote from James Quincey, Coca-Cola's Chairman and CEO, regarding the Georgia voter integrity law.",
#       "James Quincey": "The source is James Quincey, Coca-Cola's Chairman and CEO. He provides a statement about the Georgia voter integrity law, which is quoted in the article.",
#       "The Mark Levin Show": "This source is grouped with"
#     }
#   },
#   {
#     "article_url": "www.forbes.com/sites/erinnemagee/2019/03/30/hacks-for-working-remotely-while-traveling/",
#     "Sources": {
#       "Journalist": "The journalist is the author of the article, providing personal anecdotes and experiences as a remote worker and traveler. They share their own motivations, habits, and tips for staying productive while traveling, including their career path and family life.",
#       "Studies": "The studies source provides statistical information and trends about remote work, including the growing number of people working remotely and the benefits of flexibility and balance. The studies cited suggest that more than half of the population will be working remotely by 2020.",
#       "Take Advantage Of The Traveler's High": "This source provides tips and advice on how to stay productive while traveling, including taking advantage of early mornings, finding inviting workspaces, and using tablets and keyboards to stay connected. The source also emphasizes the importance of coffee and finding ways to stay energized while on the go.",
#       "Live In Sneakers": "Live In Sneakers is a source that provides advice on staying active and healthy while working remotely, including the importance of taking breaks, getting outside, and exercising. The source also recommends specific products, such as sneakers and compression socks, that can help remote workers stay comfortable and productive.",
#       "Invest In A Tablet": "This source provides information on the benefits of using a tablet for remote work, including its portability and accessibility. The source suggests that a tablet can be a great option for quick trips or packed itineraries.",
#       "Copper Cow": "Copper Cow is a brand that provides pour-over coffee in travel packs, which is recommended by the journalist as a lifesaver for staying caffeinated while traveling.",
#       "Julia Cameron": "Julia Cameron is an author who wrote \"The Artist's Way\", a book that provides guidance on cultivating creativity and productivity. The book recommends morning pages, a stream-of-consciousness journaling practice, as a way to clear the mind and stay focused.",
#       "Exercise Your Senses": "This source provides advice on taking breaks and practicing self-care while working remotely, including the importance of focusing on nourishment and indulging the senses.}"
#     }
#   }
# ]
